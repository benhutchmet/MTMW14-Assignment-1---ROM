# %%
# %run Functions.ipynb # Import the functions for the tasks

# %run Stability.ipynb # Import the functions for the stability analysis in
# Task A
# created by Prof. Pier Luigi Vidale (with some analysis and modifications by
# me)

# import the relevant libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Define the global variables that do not change throughout

# %%
# Define the global variables
# These do not change throughout the tasks

b_0 = 2.5
gamma = 0.75
c = 1
r = 0.25
alpha = 0.125
xi_2 = 0
mu_c = 2/3 # critical value of coupling parameter

# set up the non-dimensionalised constants
# set up the non-dimensionalised constants
Tnd = 7.5 # (K) SST anomalies
hnd = 150 # (m) thermocline depth
tnd = 2   # (months) time-scale

# %% [markdown]
# # Task A #
#
# The values used for the neutral linear (deterministic) case in Task A are:
#
# - $\mu = \mu_c = 2/3$ coupling parameter set to its critical value.
#
# - $e_n = 0$ linear scheme.
#
# - $\xi_{1,2} = 0$ no external forcing.
#
# The model produces stable oscillation with a period of approximately 41 months and a time step ($\Delta t$) of 1 day (non-dimensionalised).

# %%
Task_A_plotting()

# %% [markdown]
# ## Stability analysis ##
#
# For the stability analysis in Task A, we explore the stability of the explicit Euler scheme by looking at the magnitude of amplification factor 'A' through eigenvalue analysis.
#
# Code from Prof. Pier Luigi Vidale is used to plot the stability regions of the explicit Euler and Runge-Kutta schemes.

# %%
Task_A_stability_analysis()

# %% [markdown]
# # Task B #
#
# In Task B we explore the linear model used in Task A with sub-critical and super-critical values of the coupling parameter $\mu$. The values used are:
#
# - $\mu = \mu_{subc} = 0.5$ coupling parameter set to its sub-critical value.
#
# - $\mu = \mu_{supc} = 0.7$ coupling parameter set to its super-critical value.
#
# - $e_n = 0$ linear scheme.
#
# - $\xi_{1,2} = 0$ no external forcing.
#
# The model is run for 5 periods of approximately 41 months and a time step ($\Delta t$) of 1 day (non-dimensionalised).

# %%
Task_B()

# %% [markdown]
# # Task C #
#
# The following values are used for Task C to explore the impacts of non-linearity:
#
# - $\mu = \mu_c = 2/3$ coupling parameter set back to its critical value.
#
# - $e_n = 0.1$ non-linear scheme.
#
# - $\xi_{1,2} = 0$ no external forcing.
#
# In the second part of the Task, $\mu$ is set to a value beyond its critical value ($\mu = \mu_{supc} = 0.8$).
#
# The model is run for 5 periods of approximately 41 months and a time step ($\Delta t$) of 1 day (non-dimensionalised).

# %%
Task_C()
# Out:
# C:\Users\Ben Hutchins\AppData\Local\Temp\ipykernel_16996\1704062385.py:56: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(plt.cm.ScalarMappable(cmap=cmap), label='Time (fraction)')
# C:\Users\Ben Hutchins\AppData\Local\Temp\ipykernel_16996\1704062385.py:85: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(plt.cm.ScalarMappable(cmap=cmap), label='Time (fraction)')

# %% [markdown]
# # Task D #
#
# The following values are used for Task D to test the self-excitation hypothesis:
#
# - $\mu = \mu_0 \biggl( 1 + \mu_{ann} \cos{\biggl(\frac{2 \pi t}{\tau} - \frac{5 \pi}{6} \biggr)} \biggr) $ coupling parameter set to vary on an annual cycle.
#
# - $e_n = 0.1$ non-linear scheme.
#
# - $\xi_{1,2} = 0$ no external forcing.
#
# - $mu_0 = 0.75$ base value of $\mu$.
#
# - $mu_{ann} = 0.2$ variability of $\mu$ on annual cycle.
#
# - $\tau = 12$ months (1 year).
#
# The model is run for 5 periods of approximately 41 months and a time step ($\Delta t$) of 1 day (non-dimensionalised).

# %%
Task_D()
# Out:
# C:\Users\Ben Hutchins\AppData\Local\Temp\ipykernel_16996\2348745385.py:58: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(plt.cm.ScalarMappable(cmap=cmap), label='Time (fraction)')

# %% [markdown]
# # Task E #
#
# The following variables were used for Task E to explore the impacts of stochastic forcing on the ROM.
#
# - $\xi_1 = f_{ann} \cos{\biggl(\frac{2 \pi t}{\tau} \biggr)} + f_{ran} W \frac{\tau_{corr}}{\Delta t}$ stochastic forcing added in the form of random wind stress.
#
# - $\mu = \mu_0 \biggl( 1 + \mu_{ann} \cos{\biggl(\frac{2 \pi t}{\tau} - \frac{5 \pi}{6} \biggr)} \biggr) $ coupling parameter set to vary on an annual cycle.
#
# - W number between -1 and +1 picked at random with uniform probability.
#
# - $\tau_{cor} = 1$ day (correlation time scale).
#
# - $f_{ann} = 0.02$ the annual forcing.
#
# - $f_{ran} = 0.2$ the random forcing variabilty.
#
# - $e_n = 0$ linear scheme.
#
# - $\mu_0 = 0.75$ base value of $\mu$.
#
# - $\mu_{ann} = 0.2$ variability of $\mu$ on annual cycle.
#
# - $\tau = 12$ months (1 year).
#
# The model is run for 5 periods of approximately 41 months and a time step ($\Delta t$) of 1 day (non-dimensionalised).

# %%
# run task E

Task_E()
# Out:
# C:\Users\Ben Hutchins\AppData\Local\Temp\ipykernel_16996\2261171976.py:64: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(plt.cm.ScalarMappable(cmap=cmap), label='Time (fraction)')

# %% [markdown]
# # Task F #
#
# For Task F, the same conditions as Task E are used, but this time for a non-linear scheme.
#
# The following variables were used for Task E to explore the impacts of stochastic forcing on the ROM.
#
# - $\xi_1 = f_{ann} \cos{\biggl(\frac{2 \pi t}{\tau} \biggr)} + f_{ran} W \frac{\tau_{corr}}{\Delta t}$ stochastic forcing added in the form of random wind stress.
#
# - $\mu = \mu_0 \biggl( 1 + \mu_{ann} \cos{\biggl(\frac{2 \pi t}{\tau} - \frac{5 \pi}{6} \biggr)} \biggr) $ coupling parameter set to vary on an annual cycle.
#
# - W number between -1 and +1 picked at random with uniform probability.
#
# - $\tau_{cor} = 1$ day (correlation time scale).
#
# - $f_{ann} = 0.02$ the annual forcing.
#
# - $f_{ran} = 0.2$ the random forcing variabilty.
#
# - $e_n = 0.1$ non-linear scheme (different to Task E).
#
# - $\mu_0 = 0.75$ base value of $\mu$.
#
# - $\mu_{ann} = 0.2$ variability of $\mu$ on annual cycle.
#
# - $\tau = 12$ months (1 year).
#
# The model is run for 5 periods of approximately 41 months and a time step ($\Delta t$) of 1 day (non-dimensionalised).

# %%
Task_F()
# Out:
# C:\Users\Ben Hutchins\AppData\Local\Temp\ipykernel_16996\1904915628.py:62: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(plt.cm.ScalarMappable(cmap=cmap), label='Time (fraction)')

# %% [markdown]
# # Task G #
#
# The ensemble is set up with 10 initial values of $T_E$ between 0.625-1.625 and 10 initial values of $h_w$ between -0.5-0.5. Therefore, the model is run with 100 different realizations of the initial conditions of the ROM. The following parameters are used in Task G.
#
# - $\xi_1 = f_{ann} \cos{\biggl(\frac{2 \pi t}{\tau} \biggr)} + f_{ran} W \frac{\tau_{corr}}{\Delta t}$ stochastic forcing added in the form of random wind stress.
#
# - $\mu = \mu_0 \biggl( 1 + \mu_{ann} \cos{\biggl(\frac{2 \pi t}{\tau} - \frac{5 \pi}{6} \biggr)} \biggr) $ coupling parameter set to vary on an annual cycle.
#
# - W number between -1 and +1 picked at random with uniform probability.
#
# - $\tau_{cor} = 1$ day (correlation time scale).
#
# - $f_{ann} = 0.02$ the annual forcing.
#
# - $f_{ran} = 0.2$ the random forcing variabilty.
#
# - $e_n = 0.1$ non-linear scheme (different to Task E).
#
# - $\mu_0 = 0.75$ base value of $\mu$.
#
# - $\mu_{ann} = 0.2$ variability of $\mu$ on annual cycle.
#
# - $\tau = 12$ months (1 year).
#
# The model is run for 5 periods using $\Delta t = 1$ day.

# %%
# run task G

Task_G()
